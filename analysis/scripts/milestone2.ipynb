# %%
import project_functions as pf

# %%
df = pf.load_and_process('../../data/raw/AppleStore.csv')

# %%
df
# Out:
#               id                                  track_name  size_bytes  \
# 0      487119327                                 Head Soccer   121319424
# 1      930574573  Sniper 3D Assassin: Shoot to Kill Gun Game   157851648
# 2      387428400                              Infinity Blade   624107810
# 3      887947640                                CSR Racing 2  1944321024
# 4      552039496                                    The Room   338273280
# ...          ...                                         ...         ...
# 6263  1141308767           Tinkerblocks – code, create, play   185029632
# 6264  1144076945    One More Spin! - Free Vegas Casino Slots   127716352
# 6265  1151268606                           脱出ゲーム　In My Heart   160161792
# 6266  1182265441               脱出ゲーム　わたしをみつけて　-おじいさんとわたしの物語-   177498112
# 6267  1051656345                                     My8to18    10645504
#
#      currency  price  rating_count_tot  rating_count_ver  user_rating  \
# ...
